# %%
'''Code for fine-tuning Inception V3 for a new task.

Start with Inception V3 network, not including last fully connected layers.

Train a simple fully connected layer on top of these.


'''

import numpy as np
import keras
import random
from keras import optimizers
from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential, Model
from keras.layers import Dense, Activation, Flatten, Dropout
import inception_v3 as inception
import vgg16 as VGG
import prepare.collect as pc
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from PIL import Image

'''
import tensorflow as tf
from keras.backend.tensorflow_backend import set_session
config = tf.ConfigProto()
config.gpu_options.per_process_gpu_memory_fraction = 0.9
set_session(tf.Session(config=config))
'''
N_CLASSES = 2
IMSIZE = (224, 224)

XML_DIR = "../data/annotations/xmls/"
IMG_DIR = "../data/images/"
VAL_RATIO = 0.3

# TO DO:: Replace these with paths to the downloaded data.
# Training directory
# train_dir = '../data/catdog/train'
# Testing directory
# test_dir = '../data/catdog/validation'


# Start with an Inception V3 model, not including the final softmax layer.
base_model = VGG.VGG16(weights='imagenet')
print ('Loaded vgg16 model')
# Out:
# Using TensorFlow backend.
# K.image_dim_ordering: tf
# Loaded vgg16 model

# %%
# Turn off training on base model layers
for layer in base_model.layers:
    layer.trainable = False
    

# Add on new fully connected layers for the output classes.
# x = Dense(1024, activation='relu')(base_model.get_layer('fc2').output)
# x = Dropout(0.5)(x)
# predictions = Dense(N_CLASSES, activation='softmax', name='predictions')(x)

base_model_last = base_model.get_layer('flatten').output
x = Dense(4096, activation='relu', name='fc1-1')(base_model_last)
x = Dense(4096, activation='relu', name='fc1-2')(x)
predictions = Dense(N_CLASSES, activation='softmax', name='predictions')(x)

# model = Model(input=base_model.input, output=predictions)
# for layer in model.layers:
#     layer.trainable = False

y = Dense(4096, activation='relu', name='fc2-1')(base_model_last)
y = Dense(4096, activation='linear', name='fc2-2')(y)
aux_predictions = Dense(4, activation='linear', name='aux_predictions')(y)

#model = Model(input=base_model.input, output=predictions)
#model.compile(loss='categorical_crossentropy', optimizer='sgd', metrics=['accuracy'])


model = Model(input=base_model.input, output=[predictions, aux_predictions])

#not training bbox part
model.get_layer("fc2-1").trainable=False
model.get_layer("fc2-2").trainable=False
model.get_layer("aux_predictions").trainable=False

#adam = optimizers.Adam(lr=0.00001)
sgd = optimizers.SGD(lr=0.001)
model.compile(optimizer=sgd,
              loss={'predictions': 'categorical_crossentropy', 'aux_predictions': 'mean_squared_error'},
             loss_weights={'predictions': 0.5, 'aux_predictions': 0}, metrics=['accuracy'])

# model = Model(input=base_model.input, output=aux_predictions)
# model.load_weights('catdog_combine.h5',by_name=True) 


#model.compile(loss='mean_squared_error', optimizer=sgd, metrics=['accuracy'])

# %%
# Show some debug output
print (model.summary())

# print ('Trainable weights')
#model.save_weights('catdog_pretrain.h5')
#print (model.trainable_weights)
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# input_1 (InputLayer)             (None, 224, 224, 3)   0
# ____________________________________________________________________________________________________
# block1_conv1 (Convolution2D)     (None, 224, 224, 64)  1792        input_1[0][0]
# ____________________________________________________________________________________________________
# block1_conv2 (Convolution2D)     (None, 224, 224, 64)  36928       block1_conv1[0][0]
# ____________________________________________________________________________________________________
# block1_pool (MaxPooling2D)       (None, 112, 112, 64)  0           block1_conv2[0][0]
# ____________________________________________________________________________________________________
# block2_conv1 (Convolution2D)     (None, 112, 112, 128) 73856       block1_pool[0][0]
# ____________________________________________________________________________________________________
# block2_conv2 (Convolution2D)     (None, 112, 112, 128) 147584      block2_conv1[0][0]
# ____________________________________________________________________________________________________
# block2_pool (MaxPooling2D)       (None, 56, 56, 128)   0           block2_conv2[0][0]
# ____________________________________________________________________________________________________
# block3_conv1 (Convolution2D)     (None, 56, 56, 256)   295168      block2_pool[0][0]
# ____________________________________________________________________________________________________
# block3_conv2 (Convolution2D)     (None, 56, 56, 256)   590080      block3_conv1[0][0]
# ____________________________________________________________________________________________________
# block3_conv3 (Convolution2D)     (None, 56, 56, 256)   590080      block3_conv2[0][0]
# ____________________________________________________________________________________________________
# block3_pool (MaxPooling2D)       (None, 28, 28, 256)   0           block3_conv3[0][0]
# ____________________________________________________________________________________________________
# block4_conv1 (Convolution2D)     (None, 28, 28, 512)   1180160     block3_pool[0][0]
# ____________________________________________________________________________________________________
# block4_conv2 (Convolution2D)     (None, 28, 28, 512)   2359808     block4_conv1[0][0]
# ____________________________________________________________________________________________________
# block4_conv3 (Convolution2D)     (None, 28, 28, 512)   2359808     block4_conv2[0][0]
# ____________________________________________________________________________________________________
# block4_pool (MaxPooling2D)       (None, 14, 14, 512)   0           block4_conv3[0][0]
# ____________________________________________________________________________________________________
# block5_conv1 (Convolution2D)     (None, 14, 14, 512)   2359808     block4_pool[0][0]
# ____________________________________________________________________________________________________
# block5_conv2 (Convolution2D)     (None, 14, 14, 512)   2359808     block5_conv1[0][0]
# ____________________________________________________________________________________________________
# block5_conv3 (Convolution2D)     (None, 14, 14, 512)   2359808     block5_conv2[0][0]
# ____________________________________________________________________________________________________
# block5_pool (MaxPooling2D)       (None, 7, 7, 512)     0           block5_conv3[0][0]
# ____________________________________________________________________________________________________
# flatten (Flatten)                (None, 25088)         0           block5_pool[0][0]
# ____________________________________________________________________________________________________
# fc1-1 (Dense)                    (None, 4096)          102764544   flatten[0][0]
# ____________________________________________________________________________________________________
# fc2-1 (Dense)                    (None, 4096)          102764544   flatten[0][0]
# ____________________________________________________________________________________________________
# fc1-2 (Dense)                    (None, 4096)          16781312    fc1-1[0][0]
# ____________________________________________________________________________________________________
# fc2-2 (Dense)                    (None, 4096)          16781312    fc2-1[0][0]
# ____________________________________________________________________________________________________
# predictions (Dense)              (None, 2)             8194        fc1-2[0][0]
# ____________________________________________________________________________________________________
# aux_predictions (Dense)          (None, 4)             16388       fc2-2[0][0]
# ====================================================================================================
# Total params: 253,830,982
# Trainable params: 119,554,050
# Non-trainable params: 134,276,932
# ____________________________________________________________________________________________________
# None

# %%
xmlFiles = pc.listAllFiles(XML_DIR)
infoList = list(map(lambda f:pc.getInfoTupleForXml(f,IMG_DIR) ,xmlFiles))

random.shuffle(infoList)
cutIndex = int(len(infoList)*VAL_RATIO)
train_files=infoList[:cutIndex]
val_files = infoList[cutIndex:]
train_files[50]
# Out:
# ['../data/annotations/xmls/British_Shorthair_156.xml',
#  '../data/images/British_Shorthair_156.jpg',
#  0,
#  (38.0, 13.213213213213212, 69.0, 58.85885885885885),
#  (500, 333)]

# %%
#print(val_files)
np.random.seed()
img_datagen = ImageDataGenerator(rescale=1./255)

def to_categorical(y, num_classes=None):
    """Converts a class vector (integers) to binary class matrix.
    E.g. for use with categorical_crossentropy.
    # Arguments
        y: class vector to be converted into a matrix
            (integers from 0 to num_classes).
        num_classes: total number of classes.
    # Returns
        A binary matrix representation of the input.
    """
    y = np.array(y, dtype='int').ravel()
    if not num_classes:
        num_classes = np.max(y) + 1
    n = y.shape[0]
    categorical = np.zeros((n, num_classes))
    categorical[np.arange(n), y] = 1
    return categorical

def my_load_img(img_path,img_datagen,size):
    img = image.load_img(img_path, target_size=size)
    x = image.img_to_array(img)

#     x = img_datagen.img_to_array(img)
    x = img_datagen.random_transform(x)
    x = img_datagen.standardize(x)
    #x = np.expand_dims(x, axis=0)
    return x
def my_img_generator(files,img_datagen,batch_size,bbox=False):
#     index_array = np.random.permutation(len(files))
    
    index = 0
    count = 0
    img_datas=[]
    img_labels=[]
    img_bboxes=[]
    while 1:
        # create numpy arrays of input data
        # and labels, from each line in the file
        if count < batch_size:
            img_datas.append(my_load_img(files[index][1],img_datagen,IMSIZE))
    #                 lable=[0.0,0.0]
    #                 lable[files[index][1]]=1.0
            img_labels.append(files[index][2])
            if bbox:
                img_bboxes.append(np.array(files[index][3]))
            index=(index+1)%len(files)
            count+=1
        else:
            count=0
            #print(img_datas)
            one_hot_labels=to_categorical(img_labels, num_classes=2)
            if bbox:
                yield (np.array(img_datas),[np.array(one_hot_labels),np.array(img_bboxes)])
                # yield (np.array(img_datas),np.array(img_bboxes))
            else:
                yield (np.array(img_datas),np.array(one_hot_labels))
            img_datas = []
            img_labels = []
            img_bboxes=[]
#             random.shuffle(files)
            

batch_size=32
# t = next(my_img_generator(train_files,img_datagen,batch_size))

# model.load_weights('catdog_pretrain_nf.h5') 
# train_data
# train_data.shape
my_train_generator = my_img_generator(train_files,img_datagen,batch_size,True)
my_val_generator = my_img_generator(val_files,img_datagen,batch_size,True)

#train_datagen = ImageDataGenerator(rescale=1./255)
# train_generator = train_datagen.flow_from_directory(
#         train_dir,  # this is the target directory
#         target_size=IMSIZE,  # all images will be resized to 299x299 Inception V3 input
#         batch_size=batch_size,
#         class_mode='categorical')

#test_datagen = ImageDataGenerator(rescale=1./255)
# test_generator = test_datagen.flow_from_directory(
#         test_dir,  # this is the target directory
#         target_size=IMSIZE,  # all images will be resized to 299x299 Inception V3 input
#         batch_size=batch_size,
#         class_mode='categorical')

#print(next(my_train_generator)[1])
# print(a[1].shape)
# print(a[1])

# %%
model.load_weights('catdog_combine_1.h5',by_name=True)

# %%
# my_train_generator = my_img_generator(train_files,img_datagen,32)
# my_val_generator = my_img_generator(val_files,img_datagen,32)
# model.fit_generator(
#         my_train_generator,
#         samples_per_epoch=128,
#         nb_epoch=10,
#         validation_data=test_datagen,
#         verbose=2,
#         nb_val_samples=128)

model.fit_generator(
        my_train_generator,
        samples_per_epoch=128,
        nb_epoch=50,
        validation_data=my_val_generator,
        verbose=2,
        nb_val_samples=128)
model.save_weights('catdog_combine_1.h5')
# Out:
# Epoch 1/50
# 6s - loss: 0.1188 - predictions_loss: 0.2376 - aux_predictions_loss: 96.5082 - predictions_acc: 0.8672 - aux_predictions_acc: 0.8047 - val_loss: 0.1519 - val_predictions_loss: 0.3039 - val_aux_predictions_loss: 64.0934 - val_predictions_acc: 0.8438 - val_aux_predictions_acc: 0.8281
# Epoch 2/50
# 3s - loss: 0.1000 - predictions_loss: 0.2000 - aux_predictions_loss: 62.6169 - predictions_acc: 0.9219 - aux_predictions_acc: 0.8516 - val_loss: 0.1466 - val_predictions_loss: 0.2932 - val_aux_predictions_loss: 96.8909 - val_predictions_acc: 0.8281 - val_aux_predictions_acc: 0.8203
# Epoch 3/50
# 3s - loss: 0.1543 - predictions_loss: 0.3086 - aux_predictions_loss: 76.6213 - predictions_acc: 0.8438 - aux_predictions_acc: 0.8125 - val_loss: 0.1343 - val_predictions_loss: 0.2687 - val_aux_predictions_loss: 59.0221 - val_predictions_acc: 0.9062 - val_aux_predictions_acc: 0.8359
# Epoch 4/50
# 3s - loss: 0.1504 - predictions_loss: 0.3007 - aux_predictions_loss: 78.7711 - predictions_acc: 0.8359 - aux_predictions_acc: 0.8203 - val_loss: 0.1528 - val_predictions_loss: 0.3055 - val_aux_predictions_loss: 68.6653 - val_predictions_acc: 0.8672 - val_aux_predictions_acc: 0.8281
# Epoch 5/50
# 3s - loss: 0.1497 - predictions_loss: 0.2994 - aux_predictions_loss: 91.0016 - predictions_acc: 0.8672 - aux_predictions_acc: 0.8125 - val_loss: 0.1374 - val_predictions_loss: 0.2747 - val_aux_predictions_loss: 81.8293 - val_predictions_acc: 0.8750 - val_aux_predictions_acc: 0.7812
# Epoch 6/50
# 3s - loss: 0.1295 - predictions_loss: 0.2591 - aux_predictions_loss: 71.6229 - predictions_acc: 0.8984 - aux_predictions_acc: 0.7812 - val_loss: 0.1291 - val_predictions_loss: 0.2583 - val_aux_predictions_loss: 69.4859 - val_predictions_acc: 0.9141 - val_aux_predictions_acc: 0.8516
# Epoch 7/50
# 3s - loss: 0.1269 - predictions_loss: 0.2538 - aux_predictions_loss: 67.2139 - predictions_acc: 0.8906 - aux_predictions_acc: 0.7969 - val_loss: 0.1022 - val_predictions_loss: 0.2045 - val_aux_predictions_loss: 82.9208 - val_predictions_acc: 0.9453 - val_aux_predictions_acc: 0.7969
# Epoch 8/50
# 3s - loss: 0.1508 - predictions_loss: 0.3015 - aux_predictions_loss: 70.5679 - predictions_acc: 0.8672 - aux_predictions_acc: 0.8203 - val_loss: 0.1136 - val_predictions_loss: 0.2271 - val_aux_predictions_loss: 58.7244 - val_predictions_acc: 0.9062 - val_aux_predictions_acc: 0.8438
# Epoch 9/50
# 4s - loss: 0.1330 - predictions_loss: 0.2660 - aux_predictions_loss: 83.3802 - predictions_acc: 0.8984 - aux_predictions_acc: 0.8516 - val_loss: 0.1255 - val_predictions_loss: 0.2509 - val_aux_predictions_loss: 77.5263 - val_predictions_acc: 0.8906 - val_aux_predictions_acc: 0.8359
# Epoch 10/50
# 3s - loss: 0.1037 - predictions_loss: 0.2074 - aux_predictions_loss: 83.7526 - predictions_acc: 0.9375 - aux_predictions_acc: 0.8516 - val_loss: 0.1201 - val_predictions_loss: 0.2402 - val_aux_predictions_loss: 65.7856 - val_predictions_acc: 0.8984 - val_aux_predictions_acc: 0.9062
# Epoch 11/50
# 3s - loss: 0.1165 - predictions_loss: 0.2330 - aux_predictions_loss: 71.6004 - predictions_acc: 0.9062 - aux_predictions_acc: 0.8359 - val_loss: 0.1056 - val_predictions_loss: 0.2111 - val_aux_predictions_loss: 66.4812 - val_predictions_acc: 0.9219 - val_aux_predictions_acc: 0.8906
# Epoch 12/50
# 3s - loss: 0.1304 - predictions_loss: 0.2608 - aux_predictions_loss: 74.6012 - predictions_acc: 0.8594 - aux_predictions_acc: 0.7969 - val_loss: 0.1224 - val_predictions_loss: 0.2448 - val_aux_predictions_loss: 70.0831 - val_predictions_acc: 0.9141 - val_aux_predictions_acc: 0.8828
# Epoch 13/50
# 4s - loss: 0.1563 - predictions_loss: 0.3127 - aux_predictions_loss: 86.4106 - predictions_acc: 0.8281 - aux_predictions_acc: 0.7812 - val_loss: 0.1302 - val_predictions_loss: 0.2604 - val_aux_predictions_loss: 74.2692 - val_predictions_acc: 0.8984 - val_aux_predictions_acc: 0.8047
# Epoch 14/50
# 3s - loss: 0.1435 - predictions_loss: 0.2871 - aux_predictions_loss: 88.4290 - predictions_acc: 0.9062 - aux_predictions_acc: 0.8203 - val_loss: 0.1266 - val_predictions_loss: 0.2532 - val_aux_predictions_loss: 73.4610 - val_predictions_acc: 0.9219 - val_aux_predictions_acc: 0.8516
# Epoch 15/50
# 3s - loss: 0.1169 - predictions_loss: 0.2338 - aux_predictions_loss: 66.9377 - predictions_acc: 0.9062 - aux_predictions_acc: 0.7734 - val_loss: 0.1193 - val_predictions_loss: 0.2387 - val_aux_predictions_loss: 59.4561 - val_predictions_acc: 0.9141 - val_aux_predictions_acc: 0.8125
# Epoch 16/50
# 3s - loss: 0.1452 - predictions_loss: 0.2905 - aux_predictions_loss: 68.9744 - predictions_acc: 0.8516 - aux_predictions_acc: 0.8359 - val_loss: 0.1535 - val_predictions_loss: 0.3070 - val_aux_predictions_loss: 65.9900 - val_predictions_acc: 0.8750 - val_aux_predictions_acc: 0.8359
# Epoch 17/50
# 3s - loss: 0.1315 - predictions_loss: 0.2630 - aux_predictions_loss: 68.3383 - predictions_acc: 0.8984 - aux_predictions_acc: 0.8516 - val_loss: 0.1307 - val_predictions_loss: 0.2615 - val_aux_predictions_loss: 57.2367 - val_predictions_acc: 0.8750 - val_aux_predictions_acc: 0.8281
# Epoch 18/50
# 3s - loss: 0.1195 - predictions_loss: 0.2389 - aux_predictions_loss: 99.5749 - predictions_acc: 0.9297 - aux_predictions_acc: 0.8047 - val_loss: 0.1127 - val_predictions_loss: 0.2253 - val_aux_predictions_loss: 94.6219 - val_predictions_acc: 0.8984 - val_aux_predictions_acc: 0.8125
# Epoch 19/50
# 3s - loss: 0.0949 - predictions_loss: 0.1898 - aux_predictions_loss: 70.5738 - predictions_acc: 0.9219 - aux_predictions_acc: 0.8438 - val_loss: 0.1401 - val_predictions_loss: 0.2801 - val_aux_predictions_loss: 59.9488 - val_predictions_acc: 0.8906 - val_aux_predictions_acc: 0.8438
# Epoch 20/50
# 3s - loss: 0.1241 - predictions_loss: 0.2482 - aux_predictions_loss: 63.8063 - predictions_acc: 0.8906 - aux_predictions_acc: 0.8594 - val_loss: 0.1435 - val_predictions_loss: 0.2870 - val_aux_predictions_loss: 73.2422 - val_predictions_acc: 0.8906 - val_aux_predictions_acc: 0.8203
# Epoch 21/50
# 3s - loss: 0.1391 - predictions_loss: 0.2783 - aux_predictions_loss: 87.2130 - predictions_acc: 0.8438 - aux_predictions_acc: 0.7891 - val_loss: 0.1288 - val_predictions_loss: 0.2576 - val_aux_predictions_loss: 80.3955 - val_predictions_acc: 0.8984 - val_aux_predictions_acc: 0.7969
# Epoch 22/50
# 3s - loss: 0.1336 - predictions_loss: 0.2672 - aux_predictions_loss: 86.9286 - predictions_acc: 0.8984 - aux_predictions_acc: 0.7969 - val_loss: 0.1186 - val_predictions_loss: 0.2372 - val_aux_predictions_loss: 72.1710 - val_predictions_acc: 0.9219 - val_aux_predictions_acc: 0.8516
# Epoch 23/50
# 3s - loss: 0.1248 - predictions_loss: 0.2496 - aux_predictions_loss: 76.5573 - predictions_acc: 0.9219 - aux_predictions_acc: 0.8203 - val_loss: 0.0909 - val_predictions_loss: 0.1818 - val_aux_predictions_loss: 79.5962 - val_predictions_acc: 0.9688 - val_aux_predictions_acc: 0.7969
# Epoch 24/50
# 3s - loss: 0.1127 - predictions_loss: 0.2255 - aux_predictions_loss: 69.8025 - predictions_acc: 0.9062 - aux_predictions_acc: 0.7891 - val_loss: 0.1139 - val_predictions_loss: 0.2279 - val_aux_predictions_loss: 61.6394 - val_predictions_acc: 0.8984 - val_aux_predictions_acc: 0.8906
# Epoch 25/50
# 3s - loss: 0.1664 - predictions_loss: 0.3328 - aux_predictions_loss: 73.1237 - predictions_acc: 0.8203 - aux_predictions_acc: 0.8125 - val_loss: 0.1153 - val_predictions_loss: 0.2306 - val_aux_predictions_loss: 77.8932 - val_predictions_acc: 0.9297 - val_aux_predictions_acc: 0.8125
# Epoch 26/50
# 3s - loss: 0.1228 - predictions_loss: 0.2456 - aux_predictions_loss: 70.6103 - predictions_acc: 0.8984 - aux_predictions_acc: 0.8672 - val_loss: 0.1154 - val_predictions_loss: 0.2308 - val_aux_predictions_loss: 69.3138 - val_predictions_acc: 0.8984 - val_aux_predictions_acc: 0.8984
# Epoch 27/50
# 3s - loss: 0.0905 - predictions_loss: 0.1809 - aux_predictions_loss: 96.2694 - predictions_acc: 0.9609 - aux_predictions_acc: 0.7969 - val_loss: 0.1087 - val_predictions_loss: 0.2174 - val_aux_predictions_loss: 69.7780 - val_predictions_acc: 0.9531 - val_aux_predictions_acc: 0.8828
# Epoch 28/50
# 3s - loss: 0.1007 - predictions_loss: 0.2013 - aux_predictions_loss: 66.2522 - predictions_acc: 0.9141 - aux_predictions_acc: 0.8594 - val_loss: 0.0977 - val_predictions_loss: 0.1954 - val_aux_predictions_loss: 68.8998 - val_predictions_acc: 0.9375 - val_aux_predictions_acc: 0.8828
# Epoch 29/50
# 3s - loss: 0.1248 - predictions_loss: 0.2497 - aux_predictions_loss: 76.9914 - predictions_acc: 0.8828 - aux_predictions_acc: 0.8203 - val_loss: 0.1307 - val_predictions_loss: 0.2614 - val_aux_predictions_loss: 73.6502 - val_predictions_acc: 0.8906 - val_aux_predictions_acc: 0.8203
# Epoch 30/50
# 3s - loss: 0.1361 - predictions_loss: 0.2721 - aux_predictions_loss: 83.4972 - predictions_acc: 0.8594 - aux_predictions_acc: 0.7812 - val_loss: 0.1146 - val_predictions_loss: 0.2292 - val_aux_predictions_loss: 72.6997 - val_predictions_acc: 0.9219 - val_aux_predictions_acc: 0.8281
# Epoch 31/50
# 3s - loss: 0.1352 - predictions_loss: 0.2703 - aux_predictions_loss: 88.1762 - predictions_acc: 0.9141 - aux_predictions_acc: 0.8281 - val_loss: 0.1218 - val_predictions_loss: 0.2437 - val_aux_predictions_loss: 60.4527 - val_predictions_acc: 0.9219 - val_aux_predictions_acc: 0.8047
# Epoch 32/50
# 3s - loss: 0.1260 - predictions_loss: 0.2520 - aux_predictions_loss: 73.6163 - predictions_acc: 0.8906 - aux_predictions_acc: 0.7656 - val_loss: 0.1224 - val_predictions_loss: 0.2447 - val_aux_predictions_loss: 70.0481 - val_predictions_acc: 0.9062 - val_aux_predictions_acc: 0.8203
# Epoch 33/50
# 3s - loss: 0.1197 - predictions_loss: 0.2394 - aux_predictions_loss: 61.3942 - predictions_acc: 0.8906 - aux_predictions_acc: 0.8203 - val_loss: 0.1198 - val_predictions_loss: 0.2396 - val_aux_predictions_loss: 63.7060 - val_predictions_acc: 0.9141 - val_aux_predictions_acc: 0.8047
# Epoch 34/50
# 3s - loss: 0.1234 - predictions_loss: 0.2467 - aux_predictions_loss: 71.8514 - predictions_acc: 0.8984 - aux_predictions_acc: 0.8281 - val_loss: 0.1030 - val_predictions_loss: 0.2061 - val_aux_predictions_loss: 86.3660 - val_predictions_acc: 0.9219 - val_aux_predictions_acc: 0.7969
# Epoch 35/50
# 3s - loss: 0.1290 - predictions_loss: 0.2579 - aux_predictions_loss: 91.1897 - predictions_acc: 0.8984 - aux_predictions_acc: 0.8203 - val_loss: 0.1306 - val_predictions_loss: 0.2612 - val_aux_predictions_loss: 64.2809 - val_predictions_acc: 0.8984 - val_aux_predictions_acc: 0.8359
# Epoch 36/50
# 3s - loss: 0.0902 - predictions_loss: 0.1805 - aux_predictions_loss: 76.3429 - predictions_acc: 0.9453 - aux_predictions_acc: 0.8828 - val_loss: 0.1212 - val_predictions_loss: 0.2424 - val_aux_predictions_loss: 68.4316 - val_predictions_acc: 0.8984 - val_aux_predictions_acc: 0.8438
# Epoch 37/50
# 3s - loss: 0.1122 - predictions_loss: 0.2243 - aux_predictions_loss: 68.3229 - predictions_acc: 0.9062 - aux_predictions_acc: 0.8359 - val_loss: 0.1343 - val_predictions_loss: 0.2685 - val_aux_predictions_loss: 77.7349 - val_predictions_acc: 0.9297 - val_aux_predictions_acc: 0.8047
# Epoch 38/50
# 3s - loss: 0.1139 - predictions_loss: 0.2278 - aux_predictions_loss: 77.8467 - predictions_acc: 0.8984 - aux_predictions_acc: 0.7969 - val_loss: 0.1269 - val_predictions_loss: 0.2539 - val_aux_predictions_loss: 86.0522 - val_predictions_acc: 0.8984 - val_aux_predictions_acc: 0.8359
# Epoch 39/50
# 3s - loss: 0.1383 - predictions_loss: 0.2766 - aux_predictions_loss: 88.2565 - predictions_acc: 0.8672 - aux_predictions_acc: 0.7812 - val_loss: 0.0807 - val_predictions_loss: 0.1614 - val_aux_predictions_loss: 74.8516 - val_predictions_acc: 0.9688 - val_aux_predictions_acc: 0.7891
# Epoch 40/50
# 3s - loss: 0.1278 - predictions_loss: 0.2556 - aux_predictions_loss: 82.7838 - predictions_acc: 0.9375 - aux_predictions_acc: 0.8047 - val_loss: 0.1207 - val_predictions_loss: 0.2413 - val_aux_predictions_loss: 69.1100 - val_predictions_acc: 0.8984 - val_aux_predictions_acc: 0.8672
# Epoch 41/50
# 3s - loss: 0.1106 - predictions_loss: 0.2213 - aux_predictions_loss: 75.6775 - predictions_acc: 0.9141 - aux_predictions_acc: 0.7812 - val_loss: 0.1039 - val_predictions_loss: 0.2078 - val_aux_predictions_loss: 70.7485 - val_predictions_acc: 0.9375 - val_aux_predictions_acc: 0.7812
# Epoch 42/50
# 3s - loss: 0.1471 - predictions_loss: 0.2941 - aux_predictions_loss: 68.0311 - predictions_acc: 0.8438 - aux_predictions_acc: 0.8281 - val_loss: 0.1175 - val_predictions_loss: 0.2350 - val_aux_predictions_loss: 68.5117 - val_predictions_acc: 0.8906 - val_aux_predictions_acc: 0.8906
# Epoch 43/50
# 3s - loss: 0.1082 - predictions_loss: 0.2165 - aux_predictions_loss: 62.0940 - predictions_acc: 0.9141 - aux_predictions_acc: 0.8594 - val_loss: 0.1140 - val_predictions_loss: 0.2280 - val_aux_predictions_loss: 70.1693 - val_predictions_acc: 0.9453 - val_aux_predictions_acc: 0.8828
# Epoch 44/50
# 3s - loss: 0.1125 - predictions_loss: 0.2250 - aux_predictions_loss: 104.1655 - predictions_acc: 0.9219 - aux_predictions_acc: 0.8125 - val_loss: 0.0869 - val_predictions_loss: 0.1737 - val_aux_predictions_loss: 76.9871 - val_predictions_acc: 0.9531 - val_aux_predictions_acc: 0.8750
# Epoch 45/50
# 4s - loss: 0.0871 - predictions_loss: 0.1743 - aux_predictions_loss: 69.8793 - predictions_acc: 0.9453 - aux_predictions_acc: 0.8359 - val_loss: 0.1472 - val_predictions_loss: 0.2944 - val_aux_predictions_loss: 73.7538 - val_predictions_acc: 0.8906 - val_aux_predictions_acc: 0.8359
# Epoch 46/50
# 3s - loss: 0.1123 - predictions_loss: 0.2245 - aux_predictions_loss: 58.2046 - predictions_acc: 0.9141 - aux_predictions_acc: 0.8672 - val_loss: 0.1264 - val_predictions_loss: 0.2527 - val_aux_predictions_loss: 75.1534 - val_predictions_acc: 0.9062 - val_aux_predictions_acc: 0.8359
# Epoch 47/50
# 4s - loss: 0.1207 - predictions_loss: 0.2414 - aux_predictions_loss: 91.3569 - predictions_acc: 0.8672 - aux_predictions_acc: 0.7734 - val_loss: 0.1118 - val_predictions_loss: 0.2237 - val_aux_predictions_loss: 66.4799 - val_predictions_acc: 0.9375 - val_aux_predictions_acc: 0.8125
# Epoch 48/50
# 3s - loss: 0.1328 - predictions_loss: 0.2656 - aux_predictions_loss: 85.1902 - predictions_acc: 0.9141 - aux_predictions_acc: 0.8203 - val_loss: 0.1146 - val_predictions_loss: 0.2291 - val_aux_predictions_loss: 63.1566 - val_predictions_acc: 0.9141 - val_aux_predictions_acc: 0.8203
# Epoch 49/50
# 3s - loss: 0.1149 - predictions_loss: 0.2299 - aux_predictions_loss: 77.0239 - predictions_acc: 0.9219 - aux_predictions_acc: 0.8047 - val_loss: 0.1155 - val_predictions_loss: 0.2310 - val_aux_predictions_loss: 72.5446 - val_predictions_acc: 0.9375 - val_aux_predictions_acc: 0.8125
# Epoch 50/50
# 3s - loss: 0.1096 - predictions_loss: 0.2191 - aux_predictions_loss: 69.6010 - predictions_acc: 0.9062 - aux_predictions_acc: 0.7891 - val_loss: 0.1113 - val_predictions_loss: 0.2226 - val_aux_predictions_loss: 81.7815 - val_predictions_acc: 0.9141 - val_aux_predictions_acc: 0.7891

# %%
# img_path = '../data/cat2.jpg'
test_img = train_files[0]
img_path = test_img[1]
# img = image.load_img(img_path, target_size=IMSIZE)
# x = image.img_to_array(img)
# x = np.expand_dims(x, axis=0)

# x = inception.preprocess_input(x)
# x = my_load_img(img_path,img_datagen,IMSIZE)
# x = np.expand_dims(x, axis=0)
# preds = model.predict(x)[0]
# print('Predicted:', preds)
# width=test_img[4][0]
# height= test_img[4][1]
# actual_preds=[preds[0]*width*0.01,preds[1]*height*0.01,preds[2]*width*0.01,preds[3]*height*0.01]
# print('Actual_preds',actual_preds)

def getPredForImg(img_path):
    x = my_load_img(img_path,img_datagen,IMSIZE)
    x = np.expand_dims(x, axis=0)
    preds = model.predict(x)
    return preds
def testImage(img_path,preds):  
    size = Image.open(img_path).size
    width=size[0]
    height=size[1]
    im = np.array(Image.open(img_path), dtype=np.uint8)
    # Create figure and axes
    fig,ax = plt.subplots(1)

    # Display the image
    ax.imshow(im)
    actual_preds=[preds[0]*width*0.01,preds[1]*height*0.01,preds[2]*width*0.01,preds[3]*height*0.01]
    # Create a Rectangle patch
    rect = patches.Rectangle((actual_preds[0],actual_preds[1]),actual_preds[2]-actual_preds[0],actual_preds[3]-actual_preds[1],linewidth=1,edgecolor='r',facecolor='none')

    # Add the patch to the Axes
    ax.add_patch(rect)
    plt.show()
    return
files = pc.listAllFiles("../data/test/")
random.shuffle(files)
for f in files[30:40]:
    preds = getPredForImg(f)
    print(preds)
    testImage(f,preds[1][0])
    
# preds = getPredForImg("../data/bill.jpg")
# testImage("../data/bill.jpg",preds)
# Out:
# [array([[ 0.00138626,  0.99861372]], dtype=float32), array([[ 15.269701  ,   9.14763927,  72.87234497,  61.56257629]], dtype=float32)]
# [array([[ 0.09114135,  0.90885866]], dtype=float32), array([[ 42.73282242,  24.17757797,  63.85802078,  61.74715424]], dtype=float32)]
# [array([[ 0.09657196,  0.90342808]], dtype=float32), array([[ 24.96319962,   4.39060068,  95.45166779,  83.46823883]], dtype=float32)]
# [array([[ 0.0164186 ,  0.98358142]], dtype=float32), array([[ 21.79852676,   5.91358423,  87.84641266,  87.12695312]], dtype=float32)]
# [array([[ 0.64715487,  0.35284513]], dtype=float32), array([[ 42.87636948,  36.41980362,  64.42156219,  62.08346558]], dtype=float32)]
# [array([[ 0.43262187,  0.5673781 ]], dtype=float32), array([[ 25.53476906,  24.73101425,  62.56150436,  58.20242691]], dtype=float32)]
# [array([[ 0.98763406,  0.01236592]], dtype=float32), array([[ 29.24162292,   0.22531214,  83.4197998 ,  50.38723373]], dtype=float32)]
# [array([[ 0.19437596,  0.80562395]], dtype=float32), array([[ 14.85180092,  12.91792679,  84.51942444,  60.94056702]], dtype=float32)]
# [array([[ 0.08269068,  0.91730928]], dtype=float32), array([[ 17.45445251,  18.1478672 ,  64.7113266 ,  76.34262848]], dtype=float32)]
# [array([[  8.79127765e-04,   9.99120891e-01]], dtype=float32), array([[ 25.28334618,  13.82884121,  65.70967865,  56.95874023]], dtype=float32)]

# %%
Image.open(img_path).size
# Out:
# (500, 334)
